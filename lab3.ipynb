# %% [markdown]
# <a href="https://colab.research.google.com/github/LaxmiBandi/11.2-Bootstrap-Components/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load dataset
df = pd.read_csv("canada_per_capita_income.csv")

# Independent and dependent variable
X = df[['year']]
y = df['per capita income (US$)']

# Create model
model = LinearRegression()
model.fit(X, y)

# Predict for 2020
prediction = model.predict([[2020]])
print("Predicted Per Capita Income in 2020:", prediction[0])

# Plot
plt.scatter(X, y)
plt.plot(X, model.predict(X), color='red')
plt.xlabel("Year")
plt.ylabel("Per Capita Income")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted Per Capita Income in 2020: 41288.69409441762

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv("salary.csv")

# Remove rows where YearsExperience is missing
df = df.dropna()

X = df[['YearsExperience']]
y = df['Salary']

model = LinearRegression()
model.fit(X, y)

salary_12 = model.predict([[12]])

print("Predicted Salary for 12 Years Experience:", salary_12[0])
# Out:
# Predicted Salary for 12 Years Experience: 139049.6749539778
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Slope (Coefficient):", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope (Coefficient): 9398.640601843543
# Intercept: 26265.98773185531

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("canada_per_capita_income.csv")

X = df[['year']]
y = df['per capita income (US$)']

model = LinearRegression()
model.fit(X, y)

prediction = model.predict([[2020]])
print("Predicted Income in 2020:", prediction[0])

# Visualization
plt.scatter(X, y)
plt.plot(X, model.predict(X))
plt.xlabel("Year")
plt.ylabel("Income")
plt.title("Year vs Per Capita Income")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted Income in 2020: 41288.69409441762

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv("hiring.csv")

# Convert word numbers to digits
experience_mapping = {
    'zero':0,
    'one':1,
    'two':2,
    'three':3,
    'four':4,
    'five':5,
    'six':6,
    'seven':7,
    'eight':8,
    'nine':9,
    'ten':10,
    'eleven':11,
    'twelve':12
}

df['experience'] = df['experience'].map(experience_mapping)

# Fill missing values properly (without inplace warning)
df['experience'] = df['experience'].fillna(0)
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(
    df['test_score(out of 10)'].mean()
)

X = df[['experience','test_score(out of 10)','interview_score(out of 10)']]
y = df['salary($)']

model = LinearRegression()
model.fit(X,y)

print("Salary (2 yr,9,6):", model.predict([[2,9,6]])[0])
print("Salary (12 yr,10,10):", model.predict([[12,10,10]])[0])
# Out:
# Salary (2 yr,9,6): 53290.892559447646
# Salary (12 yr,10,10): 92268.07227783566
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("R2 Score:", model.score(X, y))
# Out:
# R2 Score: 0.9639958361860579

# %%
print("Equation: Salary =", model.coef_[0], "* Experience +", model.intercept_)
# Out:
# Equation: Salary = 2827.63404314351 * Experience + 17237.330313727172
